# %% [markdown]
# # Circulos en puntos aleatorios
# ## Declaración de variables

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Aquí inicializo las variables que voy a utiliar

# %%
x = np.random.rand(100)*6
y = np.random.rand(100)*6
cx=np.random.rand(20*len(xp))
cy=np.random.rand(20*len(xp))

# %% [raw]
# Calculo las coordenadas de los puntos en cada circulo

# %%
i=0
for j in range(0,len(x),5):
    for g in range(0,360,36):
        cx[i]=(np.cos(g))+x[j]
        cy[i]=(np.sin(g))+y[j]
        i=(i+1)

# %% [raw]
# Gráfico los resultados

# %%
plt.scatter(x,y, color='r')
plt.scatter(cx,cy, color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.legend('Center')
plt.show()
